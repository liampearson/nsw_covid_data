# %%
import pandas as pd
import requests

def get_data_from_api(query):
  """
  given an api endpoint, get data and return as a dataframe
  """
  r = requests.get(query)
  x = r.json()
  df = pd.DataFrame.from_dict(x['result']['records'])
  return df



#API returns only 32k; so import via csv link
#tests = get_data_from_api('https://data.nsw.gov.au/data/api/3/action/datastore_search_sql?sql=SELECT * from "fb95de01-ad82-4716-ab9a-e15cf2c78556"')

# %% [markdown]
# # Get cases data

# %%
cases = get_data_from_api('https://data.nsw.gov.au/data/api/3/action/datastore_search_sql?sql=SELECT * from "2776dbb8-f807-4fb2-b1ed-184a6fc2c8aa"')

cases = cases.groupby(['notification_date','lga_name19'])['postcode'].count().reset_index()
cases.rename(columns={'postcode':'num_cases'}, inplace=True)
cases.groupby('notification_date')['num_cases'].sum()
cases.head()
# Out:
#   notification_date       lga_name19  num_cases
# 0        2020-01-25      Burwood (A)          1
# 1        2020-01-25  Ku-ring-gai (A)          1
# 2        2020-01-25   Parramatta (C)          1
# 3        2020-01-27     Randwick (C)          1
# 4        2020-03-01    Fairfield (C)          1

# %% [markdown]
# ## Get tests data
# the API limits the data to only 32k records, so need to import via csv:

# %%
#get tests data
import pandas as pd
import io
import requests
url="https://data.nsw.gov.au/data/datastore/dump/fb95de01-ad82-4716-ab9a-e15cf2c78556?bom=True"
s=requests.get(url).content
tests=pd.read_csv(io.StringIO(s.decode('utf-8')))

#aggregate such that have num cases per day per lga

tests = tests.groupby(['test_date', 'lga_name19'])['test_count'].sum().reset_index()
tests.head()
# Out:
#     test_date                lga_name19  test_count
# 0  2020-01-01             Blacktown (C)           1
# 1  2020-01-01                Camden (A)           2
# 2  2020-01-01            Canada Bay (A)           2
# 3  2020-01-01  Canterbury-Bankstown (A)           2
# 4  2020-01-01            Cumberland (A)           1

# %%
print("check number of records in cases:")
print(cases.shape)
print()
print("check number of records in tests:")
print(tests.shape)
print()
# Out:
# check number of records in cases:
# (2879, 3)
#
# check number of records in tests:
# (61763, 3)

# %% [markdown]
# # Merge the test data and cases data

# %%
cases_tests = tests.merge(cases, 
                          how='left', 
                          left_on=['test_date','lga_name19'],
                          right_on=['notification_date', 'lga_name19']
                          )

cases_tests
# Out:
#         test_date                lga_name19  ...  notification_date num_cases
# 0      2020-01-01             Blacktown (C)  ...                NaN       NaN
# 1      2020-01-01                Camden (A)  ...                NaN       NaN
# 2      2020-01-01            Canada Bay (A)  ...                NaN       NaN
# 3      2020-01-01  Canterbury-Bankstown (A)  ...                NaN       NaN
# 4      2020-01-01            Cumberland (A)  ...                NaN       NaN
# ...           ...                       ...  ...                ...       ...
# 61758  2021-07-23         Wingecarribee (A)  ...         2021-07-23       1.0
# 61759  2021-07-23           Wollondilly (A)  ...                NaN       NaN
# 61760  2021-07-23            Wollongong (C)  ...                NaN       NaN
# 61761  2021-07-23             Woollahra (A)  ...                NaN       NaN
# 61762  2021-07-23           Yass Valley (A)  ...                NaN       NaN
#
# [61763 rows x 5 columns]

# %%
#fill NA (no cases) with zeros
cases_tests['num_cases'] = cases_tests['num_cases'].fillna(0)
cases_tests
# Out:
#         test_date                lga_name19  ...  notification_date num_cases
# 0      2020-01-01             Blacktown (C)  ...                NaN       0.0
# 1      2020-01-01                Camden (A)  ...                NaN       0.0
# 2      2020-01-01            Canada Bay (A)  ...                NaN       0.0
# 3      2020-01-01  Canterbury-Bankstown (A)  ...                NaN       0.0
# 4      2020-01-01            Cumberland (A)  ...                NaN       0.0
# ...           ...                       ...  ...                ...       ...
# 61758  2021-07-23         Wingecarribee (A)  ...         2021-07-23       1.0
# 61759  2021-07-23           Wollondilly (A)  ...                NaN       0.0
# 61760  2021-07-23            Wollongong (C)  ...                NaN       0.0
# 61761  2021-07-23             Woollahra (A)  ...                NaN       0.0
# 61762  2021-07-23           Yass Valley (A)  ...                NaN       0.0
#
# [61763 rows x 5 columns]

# %%
#get the rate of cases per
cases_tests['positive_rate'] = cases_tests['num_cases']/cases_tests['test_count']
cases_tests
# Out:
#         test_date                lga_name19  ...  num_cases positive_rate
# 0      2020-01-01             Blacktown (C)  ...        0.0      0.000000
# 1      2020-01-01                Camden (A)  ...        0.0      0.000000
# 2      2020-01-01            Canada Bay (A)  ...        0.0      0.000000
# 3      2020-01-01  Canterbury-Bankstown (A)  ...        0.0      0.000000
# 4      2020-01-01            Cumberland (A)  ...        0.0      0.000000
# ...           ...                       ...  ...        ...           ...
# 61758  2021-07-23         Wingecarribee (A)  ...        1.0      0.002833
# 61759  2021-07-23           Wollondilly (A)  ...        0.0      0.000000
# 61760  2021-07-23            Wollongong (C)  ...        0.0      0.000000
# 61761  2021-07-23             Woollahra (A)  ...        0.0      0.000000
# 61762  2021-07-23           Yass Valley (A)  ...        0.0      0.000000
#
# [61763 rows x 6 columns]

# %%
#find the lga with highest postive rate
#cases_tests[(cases_tests['test_date']>'2021-06-01')&(cases_tests['test_count']>100)].sort_values(by='positive_rate', ascending=False)

#focus on cases/tests since June 2021
cases_tests[cases_tests['test_date']>='2021-06-01']
# Out:
#         test_date          lga_name19  ...  num_cases positive_rate
# 60144  2021-07-11       Fairfield (C)  ...       74.0      0.039509
# 60020  2021-07-10       Fairfield (C)  ...       59.0      0.039360
# 61397  2021-07-21         Burwood (A)  ...        4.0      0.019900
# 59488  2021-07-06         Burwood (A)  ...        2.0      0.015385
# 59511  2021-07-06       Fairfield (C)  ...       11.0      0.012702
# ...           ...                 ...  ...        ...           ...
# 57832  2021-06-23         Bayside (A)  ...        0.0      0.000000
# 57836  2021-06-23       Blacktown (C)  ...        0.0      0.000000
# 57839  2021-06-23  Blue Mountains (C)  ...        0.0      0.000000
# 57843  2021-06-23         Burwood (A)  ...        0.0      0.000000
# 61761  2021-07-23       Woollahra (A)  ...        0.0      0.000000
#
# [2674 rows x 6 columns]

# %%
#get the lga_name
for i in cases_tests.lga_name19.unique():
  print(i)

import numpy
numpy.savetxt("LGAs.csv", cases_tests.lga_name19.unique(), delimiter=",",fmt='%s')
# Out:
# Blacktown (C)
# Camden (A)
# Canada Bay (A)
# Canterbury-Bankstown (A)
# Cumberland (A)
# Hunters Hill (A)
# Inner West (A)
# Ku-ring-gai (A)
# Liverpool (C)
# Parramatta (C)
# Penrith (C)
# Strathfield (A)
# The Hills Shire (A)
# Wollondilly (A)
# Tweed (A)
# Oberon (A)
# Northern Beaches (A)
# Bayside (A)
# Burwood (A)
# Georges River (A)
# Fairfield (C)
# Randwick (C)
# Ryde (C)
# Sydney (C)
# Willoughby (C)
# Bathurst Regional (A)
# Campbelltown (C) (NSW)
# Maitland (C)
# Sutherland Shire (A)
# Hornsby (A)
# Newcastle (C)
# Queanbeyan-Palerang Regional (A)
# Bega Valley (A)
# Blue Mountains (C)
# Central Coast (C) (NSW)
# Snowy Valleys (A)
# Wagga Wagga (C)
# North Sydney (A)
# Armidale Regional (A)
# Bourke (A)
# Lake Macquarie (C)
# Lismore (C)
# Waverley (A)
# Woollahra (A)
# Hawkesbury (C)
# Inverell (A)
# Liverpool Plains (A)
# Shoalhaven (C)
# Singleton (A)
# Wingecarribee (A)
# Wollongong (C)
# Bellingen (A)
# Lane Cove (A)
# Mosman (A)
# Hilltops (A)
# Port Stephens (A)
# Balranald (A)
# Byron (A)
# Port Macquarie-Hastings (A)
# Kempsey (A)
# Shellharbour (C)
# Cessnock (C)
# Mid-Coast (A)
# Tamworth Regional (A)
# Kyogle (A)
# Upper Hunter Shire (A)
# Eurobodalla (A)
# Yass Valley (A)
# Richmond Valley (A)
# Cootamundra-Gundagai Regional (A)
# Edward River (A)
# Glen Innes Severn (A)
# Kiama (A)
# Ballina (A)
# Nambucca (A)
# Snowy Monaro Regional (A)
# Blayney (A)
# Cabonne (A)
# Lithgow (C)
# Mid-Western Regional (A)
# Coolamon (A)
# Goulburn Mulwaree (A)
# Greater Hume Shire (A)
# Orange (C)
# Muswellbrook (A)
# Narrabri (A)
# Dubbo Regional (A)
# Warrumbungle Shire (A)
# Coffs Harbour (C)
# Albury (C)
# Clarence Valley (A)
# Murrumbidgee (A)
# Narrandera (A)
# Leeton (A)
# Moree Plains (A)
# Walgett (A)
# Temora (A)
# Forbes (A)
# Dungog (A)
# Griffith (C)
# Uralla (A)
# Coonamble (A)
# Cowra (A)
# Lachlan (A)
# Tenterfield (A)
# Upper Lachlan Shire (A)
# Walcha (A)
# Broken Hill (C)
# Cobar (A)
# Gwydir (A)
# Parkes (A)
# Bland (A)
# Gunnedah (A)
# Narromine (A)
# Federation (A)
# Central Darling (A)
# Carrathool (A)
# Junee (A)
# Wentworth (A)
# Bogan (A)
# Warren (A)
# Weddin (A)
# Lockhart (A)
# Berrigan (A)
# Brewarrina (A)
# Gilgandra (A)
# Hay (A)
# Murray River (A)

# %%
"string"[:-3]
# Out:
# 'str'
